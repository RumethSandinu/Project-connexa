# %%
import random

import pandas as pd

# %%
df = pd.read_csv('/Users/rumethsandinu/Study/Assessments/Year 2/DSGP/Datasets/DSGP Survey (Responses).csv')
df.head()
# Out:
#              Timestamp                  Email address  \
# 0  12/11/2023 11:39:21    amethajayawardena@gmail.com
# 1  12/11/2023 11:55:12  prabathpriyanga0518@gmail.com
# 2  12/11/2023 11:55:41       lafri.20220037@iit.ac.lk
# 3  12/11/2023 11:59:02     lashanthi.dabera@gmail.com
# 4  12/11/2023 12:00:56              madhuni@gmail.com
#
#   1. How often do you order an item online ?  \
# 0                        2 - 3 times a month
# 1                                Very rarely
# 2                                Very rarely
# 3                                Very rarely
# 4                                Very rarely
#
#   2. Which of these applications or websites do you use to make a purchase ?  \
# 0                                       Daraz, Other
# 1                                       Daraz, Other
# 2                                              Daraz
# 3                            Daraz, Keells, Cargills
# 4                                              Daraz
#
# ...
