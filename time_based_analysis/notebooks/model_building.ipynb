# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../datasets/time_analysis_preprocess_dataset_ont_hot.csv')
df.head(3)
# Out:
#    time  quantity_sold_kg  item_name_7 colour pepper  \
# 0     9               1.1                      False
# 1     9               0.6                      False
# 2     9               0.5                      False
#
#    item_name_agaricus bisporus  item_name_aihao  item_name_amaranth  \
# 0                        False            False               False
# 1                        False            False               False
# 2                        False            False               False
#
#    item_name_apricot bao mushroom  item_name_basil  item_name_bell pepper  \
# 0                           False            False                  False
# 1                           False            False                  False
# 2                           False            False                  False
#
#    item_name_big broccoli  ...  item_name_zhijiang qinggengsanhua  \
# 0                   False  ...                              False
# 1                   False  ...                              False
# 2                   False  ...                              False
#
#    item_name_zhijiang red bolt  item_name_zhimaxiancai  item_name_zhuyecai  \
# 0                        False                   False               False
# 1                        False                   False               False
# 2                        False                   False               False
#
#    category_name_aquatic  category_name_cabbage  category_name_capsicum  \
# 0                  False                  False                    True
# 1                  False                  False                    True
# 2                  False                  False                   False
#
#    category_name_flower  category_name_mushroom  category_name_solanum
# 0                 False                   False                  False
# 1                 False                   False                  False
# 2                  True                   False                  False
#
# [3 rows x 160 columns]

# %%
df.shape
# Out:
# (440716, 160)

# %%
# Find the clusters using elbow method
from sklearn.cluster import KMeans
k_values = range(1,25)
wcss_error = []
for k in k_values :
    model = KMeans(n_clusters= k)
    model.fit(df)
    wcss_error.append(model.inertia_)

# %%
plt.plot(k_values, wcss_error)
plt.xlabel('K value')
plt.ylabel('WCSS error') 
plt.xticks(k_values)
plt.grid(True, linewidth = 0.5, color = 'y', linestyle = '--')

# %%
from sklearn.cluster import KMeans

# %%
# Apply K-Means algorithm
kmeans = KMeans(n_clusters=4, random_state=42)
pred = kmeans.fit_predict(df)
pred
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int32)

# %%
df_trained = df
df_trained['cluster'] = pred
df.head(3)
# Out:
#    time  quantity_sold_kg  item_name_7 colour pepper  \
# 0     9               1.1                      False
# 1     9               0.6                      False
# 2     9               0.5                      False
#
#    item_name_agaricus bisporus  item_name_aihao  item_name_amaranth  \
# 0                        False            False               False
# 1                        False            False               False
# 2                        False            False               False
#
#    item_name_apricot bao mushroom  item_name_basil  item_name_bell pepper  \
# 0                           False            False                  False
# 1                           False            False                  False
# 2                           False            False                  False
#
#    item_name_big broccoli  ...  item_name_zhijiang red bolt  \
# 0                   False  ...                        False
# 1                   False  ...                        False
# 2                   False  ...                        False
#
#    item_name_zhimaxiancai  item_name_zhuyecai  category_name_aquatic  \
# 0                   False               False                  False
# 1                   False               False                  False
# 2                   False               False                  False
#
#    category_name_cabbage  category_name_capsicum  category_name_flower  \
# 0                  False                    True                 False
# 1                  False                    True                 False
# 2                  False                   False                  True
#
#    category_name_mushroom  category_name_solanum  cluster
# 0                   False                  False        0
# 1                   False                  False        0
# 2                   False                  False        0
#
# [3 rows x 161 columns]

# %%
# Scatter plot for visualization
plt.figure(figsize=(10, 6))

# Plot each cluster
for cluster_label in df_trained['cluster'].unique():
    cluster_data = df_trained[df_trained['cluster'] == cluster_label]
    plt.scatter(cluster_data['time'], cluster_data['quantity_sold_kg'], label=f'cluster {cluster_label}')

# Plot cluster centers
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='X', s=200, c='red', label='Cluster Centers')

# Add labels and legend
plt.xlabel('time')
plt.ylabel('quantity_sold_kg')
plt.title('K-Means Clustering')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
col = pd.DataFrame(df.columns)
col.head(3)
# Out:
#                            0
# 0                       time
# 1           quantity_sold_kg
# 2  item_name_7 colour pepper

# %%
df_trained['cluster'].value_counts()
# Out:
# cluster
# 0    176762
# 1    105737
# 2     88015
# 3     70202
# Name: count, dtype: int64
